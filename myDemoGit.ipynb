# %% [markdown]
# <a href="https://colab.research.google.com/github/Veeravis/gitDemo/blob/main/myDemoGit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello GitHup")
# Out:
# hello GitHup

# %%
print("second time to sat hello")
# Out:
# second time to sat hello
